# %%
import sys
import os
import pandas as pd 
# # Add parent directory to path (works regardless of where script is run from)
# notebook_dir = os.getcwd()  # or use os.path.abspath('')
# parent_dir = os.path.dirname(notebook_dir)
# sys.path.insert(0, parent_dir)

from dataset import build_churn_snapshot_dataset
from data_generator import raw_data
dataset = build_churn_snapshot_dataset(raw_data, snapshot_freq="7D", churn_window_days=14)  # ✓ Call the function
print(dataset.head())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 11
#       9 from dataset import build_churn_snapshot_dataset
#      10 dataset = build_churn_snapshot_dataset
# ---> 11 print(dataset.head())
#
# AttributeError: 'function' object has no attribute 'head'
